# %%
import qrcode
import matplotlib.pyplot as plt

# %%
data="https://www.instagram.com/maddyyeee/?hl=en"
file_name="Insta Qr code"
image=qrcode.make(data)
image.save(file_name)
plt.imshow(image,cmap="gray")
